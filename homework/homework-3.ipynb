# %% [markdown]
# ---
#
# ### 🎓 **Professor**: Apostolos Filippas
#
# ### 📘 **Class**: Web Analytics
#
# ### 📋 **Topic**: Homework 3
#
# 🚫 **Note**: You are not allowed to share the contents of this notebook with anyone outside this class without written permission by the professor.
#
# ---
#
# > **Before you begin:** [Update your course files and Python environment safely.](https://github.com/apostolosfilippas/wa/blob/main/assets/before-you-begin.md)
#
#
# Please follow the instructions below and write your code in the code cells provided.
#
# - Feel free to comment your code as much as you think you should.
# - There are multiple correct ways to answer each question!
# - Try to do things yourself first before resorting to AI -- you will learn more that way

# %% [markdown]
# # Part 1: Lists, loops, dictionaries, and files

# %% [markdown]
# **Question 1:** Make an empty list, then use a for loop and `range` to append the numbers 1 to 20, including 20. Print the list.

# %% [markdown]
# **Question 2:** Make an empty list, then use a for loop and `range` to go through the numbers 1 to 20, including 20. Append each number whose square is larger than 40 and less than 120. Append the number itself, not its square! Print the list.

# %% [markdown]
# **Question 3.1:** Make two empty lists, then use a for loop and `range` to go through the numbers 1 to 20, including 20.
#
# - Append each number whose square is larger than 40 and less than 120 to the first list.
# - Append every number that doesn't satisfy that condition to the second list.
#
# Print the two lists.

# %% [markdown]
# **Question 3.2:** Now let's use three empty lists. Use a for loop and `range` to go through the numbers 1 to 20, including 20.
#
# - If the number's square is larger than 40 and less than 120, append the number to the first list.
# - Otherwise, if the number itself is less than 10, append it to the second list.
# - Append all remaining numbers to the third list.
#
# Each number should go into exactly one list. Print all three lists.

# %% [markdown]
# **Question 4.1:** Someone gave Drake the following gifts for Christmas. In this dictionary, each key tells us how many of a gift he received, and its value describes the gift.
#
# Run the cell below before you begin. If you want to start this question again, rerun that cell to get the original gifts back.

# %%
my_dict = {1:'partridge in a pear tree',
           2:'turtle doves',
           3:'french hens',
           4:'calling birds',
           5:'golden rings',
           6:'geese a laying',
           7:'swans a swimming',
           8:'maids a milking',
           9:'ladies dancing',
           10:'lords a leaping',
           11:'pipers piping',
           12:'drummers drumming',
           13:'platinum rings'}

# %% [markdown]
# Drake only accepts "really big" rings and "ninja" turtle doves.
#
# - Use a for loop to go through the gifts. You can loop over the dictionary keys directly, or use `.items()` to get each count and gift name together.
# - If a gift name contains `"rings"`, add `"really big "` to the beginning of the whole gift name. For example, `"golden rings"` becomes `"really big golden rings"`.
# - If a gift name contains `"turtle"`, add `"ninja "` to the beginning of the whole gift name.
# - Update the values in `my_dict`. Keep the counts and all other gift names unchanged.
#
# Print your dictionary.

# %% [markdown]
# **Question 4.2:** Using your updated dictionary from 4.1, make another dictionary with the keys and values swapped: each key should now be a gift name, and its value should be how many of that gift Drake received.
#
# Print the new dictionary.

# %% [markdown]
# **Question 4.3:** Drake would never accept fewer than six gifts of the same kind — he's quite greedy.
#
# Using the dictionary from 4.2, create a new dictionary containing **only gifts with fewer than six items**. Store the gift name as the key and the number of additional items needed to reach six as the value.
#
# Now we can give this shopping list to a member of Drake's entourage! Print the dictionary.

# %% [markdown]
# **Question 5:** Let's work with a text file.
#
# - If you cloned the repository, `shakespeare.txt` is already in `data/`. If you download files manually, get [shakespeare.txt](https://github.com/apostolosfilippas/wa/blob/main/data/shakespeare.txt) and save it in the `data` folder inside `wa`.
# - Run this notebook with the `wa` course folder as your working directory, just as we did in the loops lesson. The file path will be `data/shakespeare.txt`.
# - Read the file with Python using `with open(...)` and `encoding='utf-8'`. Store its contents in a variable.
# - Print the text of the **second sonnet** in Shakespeare's *The Sonnets*: **lines 320–333, inclusive**, in the supplied file. Print the poem as separate lines, not as the display of a Python list.
#
# Remember: the first line of a file is line 1, but its position in a Python list is 0. A slice also stops before its ending index!

# %% [markdown]
# # Part 2: Sets and copying

# %% [markdown]
# **Question 6:** Imagine we collected visitor IDs for two days. Some people visited more than once, so their IDs appear more than once too.

# %%
monday_visitors = ["user1", "user2", "user2", "user3", "user4"]
tuesday_visitors = ["user3", "user4", "user4", "user5"]

# %% [markdown]
# Convert each list to a set, then print:
#
# - The number of unique visitors on each day.
# - The IDs of the visitors who came on both days.
# - The IDs of the visitors who came on Monday but not Tuesday.
#
# Use the set operations we covered in class. The order in which the IDs appear does not matter.

# %% [markdown]
# **Question 7:** Let's check what happens when two variables refer to the same list. Before running the cell below, predict what each print statement will show.

# %%
original = ["user1", "user2"]
second = original
second.append("user3")

print(original)
print(second)

# %% [markdown]
# In the empty cell below, start again with `original = ["user1", "user2"]`. This time, make `second` a **copy** of the list before appending `"user3"` to it.
#
# Print both lists. Add a comment explaining why `original` changes in the first example but stays unchanged in your version.

# %% [markdown]
# # Part 3: Analyzing political statements
#
# In this part, you are asked to do a basic data analysis using a real-life dataset downloaded from [PolitiFact](https://www.politifact.com/).
#
# The analysis is similar to what we did with Amazon reviews in [the loops notebook](../scripts/03.2%20loops-files-working-with-data.ipynb). Look there for hints!
#
# Please follow the steps below and write your code in the cells provided. As always, there are multiple correct ways to answer each question!

# %% [markdown]
# ## Question 8: Understanding your data source
#
# Visit the www.politifact.com website and browse around. What is the main function of the website? Write your answer in the Markdown cell below.

# %% [markdown]
# ## Question 9: Data format and attributes
#
# Your data file has been pulled from the politifact website. It can be downloaded from [this link](https://github.com/apostolosfilippas/wa/blob/4e770838d55b2b4300ed18d03d99c6d86ba0436c/data/politifact_data.txt).
#
# Every line represents a different political statement that politifact has put under its microscope. The tab-separated features are the following:
# 1. Politifact Rating
# 2. Statement
# 3. Who made the statement
# 4. when the statement was made
# 5. where the statement was made
# 6. '|'-separated subjects of the statement
#
# Put the data into a list named **statements**.
# - Every element of the list should be a list with the 6 features mentioned above.
# - The 6th element of the list of features should be a list containing the subjects that the corresponding statement is about.
# - Print the entry with index 37

# %% [markdown]
# ## Question 10: The set of ratings
#
# Use your data to find all possible ratings that politifact might assign to a statement. In other words, all possible values that the first attribute can take. Store them into a set with name **ratings** and print the set.

# %% [markdown]
# ## Question 11: The distribution of ratings
#
# You are now asked to find how many times each of the possible ratings appears.
#
# I suggest you do that using a disctionary (with keys being the rating string, and values being the number of times it appears) but feel free to follow your own strategy.
#
# Print the distribution of ratings.

# %% [markdown]
# ## Question 12: Changing labels to binary
#
# Not all of the ratings seem to tell us confidently that the statement is a lie; for example some of them refer to whether the quoter has flopped on a previous statement they made, or that the statement is half true.
#
# Toward that end make a new list with name **new_statements** that contains only those entries for which the rating is 'False', 'Mostly False', 'Pants on Fire!', 'Mostly True', and 'True'.
#
# After you do this, turn the old ratings into 0 or 1 's as follows:
# - 'False', 'Mostly False', 'Pants on Fire!' should be mapped to 0
# - 'Mostly True', 'True' should be mapped to 1

# %% [markdown]
# ## Question 13: Does Trump lie? (in this data set)
#
# How many lies (0's) and how many truths (1's) that Donald Trump said are in our data set? Donald Trump's identifier is 'donald-trump'. Print the numbers

# %% [markdown]
# ## Question 14: How about Hillary and Obama? (in this data set)
#
# Perform the same exercise for Hillary, and for Obama. Their respective identifiers are 'hillary-clinton' and 'barack-obama'

# %% [markdown]
# ## Question 15: Obama's favorite subjects
#
# What are the top 10 subjects obama talks about? Use the new_statements list for this question. If one statement is on more than one subject, then it counts as a +1 for every subject it is about. Print the top 10, along with the number of mentions.

# %% [markdown]
# ## Before you submit
#
# Complete all three parts, then run the cells from top to bottom and check what they print. Add comments where they help explain your thinking, then save and submit **this completed notebook**, `homework-3.ipynb`, with its outputs visible.
#
# Make sure you upload your saved file, so we can see both your code and its results!
