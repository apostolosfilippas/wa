# %% [markdown]
# ---
#
# ### 🎓 **Professor**: Apostolos Filippas
#
# ### 📘 **Class**: Web Analytics
#
# ### 📋 **Topic**: Homework 3
#
# 🚫 **Note**: You are not allowed to share the contents of this notebook with anyone outside this class without written permission by the professor.
#
# ---

# %% [markdown]
# # Homework 3: Building a review classifier
#
# In this homework, you are tasked with creating a script/notebook that
#
# * will use your parser to collect data of many movie reviews from rotten tomatoes,
# * will use this data to build a classifier,
# * will evaluate the classifier,
# * will perform some exploratory data analysis on your data (optional).

# %% [markdown]
# ## Step 1: Use your parser to collect data
#
# Use the parser that you developed in Homework 2 to collect data from many movie reviews. The crucial data here is (i) review text---your features and (ii) the review rating---your target variable.
#
# ***Hint:** You might want to scrape more attributes than in HW2, to create more features that your predictive model will use. This could be review-specific, movie-specific, reviewer-specific data, and so on. Similarly, the number of movies and reviews you'll choose to parse and use is up to you. Learning curves might be helpful here. Generally, the more data the better.*

# %% [markdown]
# ## Step 2: Combine the data from the reviews of different movies
#
# E.g., in dataframe, your data should now at least contain the review text and the rating in different columns. Of course, you might want to add more features that you think may be informative.

# %% [markdown]
# ## Step 3: Build a classifier
#
# Build a classifier that classifies review text as negative or positive. Evaluate and report its performance.
#
# ***Hint:** follow the notebooks of Lectures 7 - 9.*

# %% [markdown]
# ## Step 4: Increase the performance of your classifier
#
# ***(optional - bonus: up to +10% of the homework grade)***
#
# Can you increase the performance of your classifier? At the very least, I expect you to do some basic text analysis, for example using 2-grams instead of 1-grams. There are many other ways to do this, including (i) getting more data, (ii) trying different models with different parameters.

# %% [markdown]
# ## Step 5: Exploratory data analysis
#
# ***(optional - bonus: up to +10% of the homework grade)***
#
# Can you provide some interesting insights by performing exploratory data analysis on your data? An example would be whether movies tend to initially receive good ratings and these ratings get worse over time, or vice versa. Try to convey your results through appropriate visualizations.

# %% [markdown]
# ## Deliverables
#
# There are two deliverables for this assignment:
#
# 1. a pdf containing a report with  the results of the analysis, including visualizations as you see fit.
# 2. your code, which should be well-commented.
# 3. there should be a link in your code from which your training set data can be downloaded.

# %% [markdown]
# ## Grading
#
# To get full points, I expect to see  data from at least 50 movies, and a working classifier.
#
# For bonus points:
#
# 1. create a very well-performing classifier
# 2. create beautiful visualizations of the results of your analysis
# 3. conduct an informative EDA and discuss your findings
#
# You can submit this assignment individually, but you also have the option to form groups
#
# - Groups should have at most 3 people. No exceptions
# - Only one submission per group, with the names of the collaborators in the beginning of the submission
