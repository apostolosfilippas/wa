# %% [markdown]
# Professor: Apostolos Filippas
#
# Class: Web Analytics
#
# Topic: Practice Problem 2 - solutions
#
# **You are not allowed to share the contents of this notebook with anyone outside this class without written permission by the professor.**
#
# # <center><font color='red'>Instructions</font></center>
# - Follow the steps below, one by one.
# - It's important that you attempt this yourself before looking at the answers key.
# - There are multiple correct ways to answer each question!
#
# **Question 1:** Make a dictionary with three entries:
# - an entry that is a list with the numbers 1,2,3 associated with key 100
# - an entry that is a list with the numbers 2,2,3 associated with key 200
# - an entry that is a list with the numbers 3,2,3 associated with key "300"

# %% [markdown]
# **Question 2:** For every value of your dictionary that is a list, append the number 5 to the end of that list. Modify your original dictionary directly, save the resulting dictionary, and print it.

# %% [markdown]
# **Question 3**: Select the list containing the last 2 elements of the list associated with key 200. Print this list

# %% [markdown]
# **Question 4**: Print all but the first and last elements of the list associated with key "300", as a list

# %% [markdown]
# **Question 5**: Sort the list associated with key "300"

# %% [markdown]
# **Question 6**: Sort the list associated with key 100, in reverse order

# %% [markdown]
# **Question 7**: Change the second value of the list associated with key 200, to the number 3

# %% [markdown]
# **Question 8**: Check whether the lists associated with key 200 and "300" are equal

# %% [markdown]
# **Question 9:** Make a python program which checks the value of variable *month* and returns the season this month is in. The string *month* can have letters in any case (e.g., both "SeptEMber" and "sePTEMBeR" should be recognized as "September"). Consider the following season mapping:
# - December to February: Winter
# - March to May: Spring
# - June to August: Summer
# - September to November: Fall
#
# Expected Output:
# If month = "SePteMBer" -> Output: Fall

# %% [markdown]
# **Question 10**: Using the dictionary from **Question 1**, retrieve the list associated with the key 400 using the `get` method. If the key doesn't exist, your program should return the list `[-1, -1, -1]`.
#
# Hint: The `get` method of a dictionary can take a default value to return if the key is not found.
#
# Expected Output:
# If the key 400 is not in your dictionary: `[-1, -1, -1]`
