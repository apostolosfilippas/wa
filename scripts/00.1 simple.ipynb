# %% [markdown]
# ---
#
# ### 🎓 **Professor**: Apostolos Filippas
#
# ### 📘 **Class**: Web Analytics
#
# ### 📋 **Topic**: Your first script
#
# 🚫 **Note**: You are not allowed to share the contents of this notebook with anyone outside this class without written permission by the professor.
#
# ---

# %%
# This is the first script for this class
# You are supposed to download, open and run it!
print("Never pay more than 20 bucks for a computer game 🐒")

# %% [markdown]
# If you get an error, open a terminal in the `wa` course folder and run `uv sync`. Then return to this notebook and select the Python interpreter whose path contains `.venv`.
#
# Do not install packages from inside the notebook; `uv` prepares the complete course environment for you.

# %%
# The course environment, including ipykernel, is installed with `uv sync`.

# %% [markdown]
# Then try to run the first cell again!
