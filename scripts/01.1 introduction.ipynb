# %% [markdown]
# ---
#
# ### 🎓 **Professor**: Apostolos Filippas
#
# ### 📘 **Class**: Web Analytics
#
# ### 📋 **Topic**: Introduction to programming and Python
#
# 🚫 **Note**: You are not allowed to share the contents of this notebook with anyone outside this class without written permission by the professor.
#
# ---

# %% [markdown]
# ## Overview
#
# This notebook introduces the basic tools and ideas we will use in class:
# - how to use the terminal and run Python with `uv`,
# - how to run notebook cells in VS Code using the `.venv` environment,
# - how to import course packages, and
# - how to work with variables, lists, and Boolean values.
#
# Do not worry if some of this feels unfamiliar. We will cover it together in class. For now, run the examples, try the practice cells, and write down your questions.
#
# **Remember:**
# - Anything that follows a hash sign (`#`) is a comment.
# - Comments are ignored by Python.

# %% [markdown]
# # 1. The Terminal
#
# The terminal is a text-based interface to the computer's operating system.
#
# It is a powerful tool that allows you to interact with your computer using text commands.
#
# Many of the things you do on your computer (like opening files, running programs, etc.) can be done through the terminal.
#
# ### 1.1 Accessing your terminal
#
# To access your terminal:
#
# | Where | How to open the terminal |
# |-------|--------------------------|
# | Mac | Press `Command + Space`, type `Terminal`, and press Return |
# | Windows | Open the Start menu, type `PowerShell`, and press Enter |
# | VS Code | Select **Terminal → New Terminal** from the menu |
#
# ### 1.2 Need-to-know commands
#
# The three most common commands in the terminal are `ls`, `cd`, and `pwd`.
#
# - `pwd`: print the current working directory
# - `ls`: list the files and directories in the current directory
# - `cd`: change the current directory
#   - `cd ..`: go up one level in the directory tree
#   - `cd ~`: go to the home directory
#   - `cd <directory_name>`: go to a specific directory
#
#
# ## 2. Running Python through the terminal
#
# ### 2.1 The Python Console/REPL
# Python has an interactive shell called a REPL (Read-Eval-Print Loop).
#
# Open a terminal in the `wa` course folder and run:
#
# ```bash
# uv run python
# ```
#
# This will open the Python shell, and you'll see a `>>>` prompt.
#
# You can then start typing Python commands, and they will be executed immediately after you press `enter`.
#
# For example, you can use it as a calculator:
#
# ```python
# >>> 5 + 5
# 10
# ```
#
# or you can use it to define variables:
#
# ```python
# >>> x = 5
# >>> y = 10
# >>> print(x + y)
# 15
# ```
#
# To exit the Python shell on any operating system, type `exit()` and press Enter.

# %%
# Run this notebook cell to use Python as a calculator

# addition
print(5 + 5)

# subtraction
print(5 - 5)

# multiplication
print(5 * 5)

# exponentiation
print(5**5)

# division
print(5 / 5)

# %% [markdown]
# ### 2.2 Running an entire script file
#
# If you save your code in a script file (`.py`), you can reuse it and run the entire file.
#
# To run a script file:
#
# ```bash
# uv run python scripts/00.2 simple.py
# ```

# %% [markdown]
# # 3. Using Jupyter Notebooks
#
# Jupyter Notebooks let you combine explanations, Python code, and results in one file.
#
# - Open this notebook in VS Code. If VS Code asks you to install the [Microsoft Jupyter extension](https://marketplace.visualstudio.com/items?itemName=ms-toolsai.jupyter), install it.
# - Run a cell by selecting its play button or pressing `Control + Enter`.
# - The first time you run a cell, VS Code may ask you to select a kernel. Choose the Python interpreter whose path contains `.venv`.
#
# ![](../assets/kernel.png)
#
# The `.venv` kernel uses the Python version and packages prepared for this course. Run the next cell to check that it works.

# %%
print("Success!")

# %% [markdown]
# You should see the message `Success!` below the cell. This means that the cell ran successfully.

# %% [markdown]
# ## 3.1 Kernel
#
# > **Important:** A notebook remembers what you have already run. Run the cells from top to bottom so that later cells have the variables and imports they need.
#
# A Jupyter Notebook works by connecting to a "kernel" - which is essentially a Python interpreter running in the background. When you run a cell, the code is sent to this kernel for execution, and the results are sent back to display in your notebook.
#
# Think of the kernel as the engine that powers your notebook. It remembers your variables and executes your code, while the notebook is the page where you write code and see results.
#
# Selecting a kernel means choosing which Python environment will run your code. Run the next cell and check that the displayed path contains `.venv`.

# %%
import sys

print("Python interpreter:", sys.executable)
print("Using the course environment:", ".venv" in sys.executable)

# %% [markdown]
# Being able to execute code line by line and visualize data directly in notebooks is incredibly powerful for data science and analysis. It allows you to:
# - Experiment and debug code interactively
# - See results immediately after each operation
# - Create rich visualizations alongside your code
#
# This interactive workflow makes it easier to explore data, test ideas, and refine an analysis than a traditional script that runs from beginning to end in a single pass.
#
# A notebook can also contain code, results, and formatted explanations that walk a reader through your work.

# %% [markdown]
# ## 3.2 Troubleshooting
#
# - If a cell keeps running and does not finish, use the kernel menu to select **Interrupt**.
# - If the notebook starts behaving unexpectedly, select **Restart Kernel**, then run the cells again from the top.
# - If an import fails, open a terminal in the `wa` folder, run `uv sync`, and make sure the notebook kernel path contains `.venv`.
# - When asking for help, save the full error message and take a screenshot of the whole VS Code window.

# %% [markdown]
# # 4. Using packages
#
# Python packages contain functions and tools. Python comes with a "standard library", and this course uses additional third-party packages. The course lists those packages in `pyproject.toml` and manages them with `uv`.
#
# ## 4.1 Preparing the course packages
#
# Open a terminal in the `wa` course folder and run:
#
# ```bash
# uv sync
# ```
#
# This creates or updates the `.venv` course environment and installs packages such as `numpy`, which is used for scientific computing with Python.
#
# Do not install packages directly from a notebook. If an import fails, make sure the terminal is in the `wa` folder, run `uv sync`, and select the Python interpreter inside `.venv` as the notebook kernel.

# %% [markdown]
# The next cell imports NumPy and gives it the short name `np`. The course packages were installed when you ran `uv sync` in the terminal.

# %%
# 4.2 Importing a package
import numpy as np

print("Successfully imported NumPy!")

# %% [markdown]
# NumPy remains installed in `.venv` after you close the notebook.
#
# If you restart the kernel or reopen the notebook, run the import cell again so that the name `np` is available in the new session.

# %% [markdown]
# # 5. Working directories and file paths
#
# The working directory is the folder Python currently treats as its starting point. We will inspect it, but we will not change it inside the notebook. Changing it can make later cells depend on hidden state.

# %%
# 5.1 View your current working directory
from pathlib import Path

current_folder = Path.cwd()
print("Current working directory:", current_folder)

# %%
# 5.2 Build paths without changing the working directory
scripts_folder = current_folder / "scripts"
data_folder = current_folder / "data"

print("Scripts folder:", scripts_folder)
print("Data folder:", data_folder)
print("Scripts folder exists:", scripts_folder.exists())
print("Data folder exists:", data_folder.exists())

# %%
# 5.3 Try it yourself: build a path to an existing file
practice_script = scripts_folder / "00.2 simple.py"

print("Practice script:", practice_script)
print("Practice script exists:", practice_script.exists())

# %% [markdown]
# # 6. Variables

# %%
# 6.1 Defining and assigning numerical values
# Python uses = for assignment
x = 5
y = 10

print(x + y)

x = x + y
print("x after addition:", x)

z = x / y
print("z =", z)

# Python is case-sensitive!
# z = Z  # This would cause an error if Z is not defined
Z = z
print("Z =", Z)
print("Type of Z:", type(Z))  # type() shows what kind of data this is

# %%
# 6.2 Try it yourself
# Change these two numbers, predict the result, and then run the cell
my_first_number = 3
my_second_number = 4

print("My result:", my_first_number + my_second_number)

# %% [markdown]
# # 7. Lists
#
# Variables don't have to be just numbers! We can store multiple values in lists.

# %%
# 7.1 Defining lists
# Python uses [] to create lists
test_results_01 = [20, 18, 17, 19, 20, 15]
test_results_02 = [18, 17, 16, 19, 19, 14]

# 7.2 Concatenating (combining) lists
all_results = test_results_01 + test_results_02
print("Combined results:", all_results)

# 7.3 Checking the type of a list
print("Type of all_results:", type(all_results))

# %%
# 7.4 Calculate the mean (average)
import numpy as np

mean_result = np.mean(all_results)
print("Mean:", mean_result)

# 7.5 Calculate the standard deviation
std_result = np.std(all_results, ddof=1)  # ddof=1 for sample std dev
print("Standard deviation:", std_result)

# %%
# 7.6 Python slicing: [start:end] where end is exclusive
# Python starts counting indexes at 0
print("Values at indexes 1 and 2:", all_results[1:3])
print("Values at indexes 1 through 4:", all_results[1:5])

# %%
# 7.7 Try it yourself
# Replace these values with your own, add one more value, and calculate the length
my_results = [10, 12, 14]
my_results.append(16)

print("My results:", my_results)
print("Number of results:", len(my_results))
print("My mean:", np.mean(my_results))

# %% [markdown]
# # 8. Boolean values

# %%
# 8.1 Checking if values are in lists
# Python uses 'in' to check membership
print("Is 5 in test_results_01?", 5 in test_results_01)
print("Is 20 in test_results_01?", 20 in test_results_01)

# %%
# 8.2 Defining and assigning Boolean values
# Python uses True/False (must be capitalized)
x = False
print("x =", x)
print("Type of x:", type(x))
y = True
print("Type of y:", type(y))

# 8.3 Negation
# Python uses 'not' to reverse a boolean value
print("not x:", not x)
print("not y:", not y)

# %%
# 8.4 Boolean operators
# Python uses 'and' for logical AND
print("x and y:", x and y)

# Python uses 'or' for logical OR
print("x or y:", x or y)

# %%
# 8.5 Equality testing
print("x == y:", x == y)
print("9 == 9:", 9 == 9)

# 8.6 Inequality testing
print("x != y:", x != y)
print("9 != 9:", 9 != 9)

# %%
# 8.7 Comparison operators
print("9 <= 9:", 9 <= 9)
print("10 <= 9:", 10 <= 9)

# 8.8 Combining logical expressions
print("(9 == 9) and (x != y):", (9 == 9) and (x != y))

# %%
# 8.9 Try it yourself
# Change one or both values, predict the result, and then run the cell
completed_setup = True
ran_this_notebook = True

ready_for_class = completed_setup and ran_this_notebook
print("Ready for class:", ready_for_class)

# %% [markdown]
# # 9. Before you submit
#
# 1. Run the notebook from top to bottom and read the output beneath each cell.
# 2. Change the examples marked **Try it yourself** and run them again.
# 3. Add a new Markdown cell below this one. Write at least one thing you learned and one question you would like us to discuss in class.
# 4. Save the notebook. Submit whatever progress you made, even if something is still confusing or did not work.
